# %% [markdown]
# <a href="https://colab.research.google.com/github/PWR91/SO_ModeloRegresionLineal_MinimosCuadrados/blob/main/ModeloMatem%C3%A1ticoSO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Investigación 2
# ### Contexto:
# Usted está trabajando en una estructura de nube.
# Se calcula que en promedio los usuarios guardan en
# Discos Duros un promedio de **7000** Megas.
# Por otro lado su servicio necesita saber cuánta memoria física agregar a la infraestructura nueva para que
# siga creciendo.
# Si usted agrega menos de 7000 megas al día, irá mal pues ya va perdiendo para el día siguiente.
# Debido a situaciones contractuales y de horas extra, el personal puede agregar hasta un **40% más** de
# memoria al día, pero si ya la memoria disponible supera los **28000 MEGAS**, solo puede agregar un **31%**.

# %% [markdown]
# 1. Modele matemáticamente cuanta es la cantidad de mínima de memoria necesaria para garantizar
# que cada día tendrá más memoria de la consumida por los usuarios, es decir siempre crecerá.
# Asuma que los 7000 megas al día de consumo son FIJOS
#
# 2. ¿Puede establecer un modelo matemática que determina dicha cantidad en función del consumo
# diario? (suponiendo que dicho consumo es fijo)

# %% [markdown]
# #Modelo Matemático Implementado:
#     Modelo Regresión Lineal por Mínimos Cuadrados
#
#
# ![image.png](data:image/png;base64,...)

# %%
#Importando librerías

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ###Entrenando modelo con otros datos para completar pregunta 1:
# ![image.png](data:image/png;base64,...)

# %%
#Creando datos para el debido entrenamiento del Modelo

x = np.array([3008,8971,7632,3431,4536,9451,7909,4917,9812,4539,8146,8029,3400,5550,
            8774,5589,3256,6450,5795,4943,4546,3475,6334,3236,9328,6169,9435,9090, 4131, 3703])
y = np.array([7521, 22429, 19081, 8579, 11341, 23629, 19774, 12294, 24531, 11349, 20366, 20074,
            8501, 13876, 21936, 13974, 8141, 16126, 14489, 12359, 11366, 8689, 15836, 8091, 23321, 15424, 23589, 22726, 10329, 9259])

# %%
#Creando directorios y Dataframe

data = {"x": x, "y": y}
df = pd.DataFrame(data)
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
#Asignando variables modelo de Regresión Lineal

model_regression = LinearRegression()
model_regression.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Creando Gráfico

fig, ax = plt.subplots(figsize=(10,5), dpi=100)
ax.set_title('Regresión Lineal Mínimos Cuadrados')
ax.set_xlabel('Megas')
ax.set_ylabel('Memoria')
ax = plt.scatter(x, y, s=100)
ax = plt.plot(x, model_regression.predict(x), color='pink')
plt.show()

# %%
#Verificando Coeficiente e Intercepción
print(model_regression.coef_)
print(model_regression.intercept_)
# Out:
# [2.49999571]
# 1.2762707780166238

# %%
#Corroborando 
## y = mx+b

2.49999571*(7000)+1.2762707780166238
# Out:
# 17501.246240778015

# %% [markdown]
# ###Entrenando modelo con otros datos para completar pregunta 2:
# ![image.png](data:image/png;base64,...)

# %%
x_test = [7000, 8000, 3000]
y_test = [17501, 20001, 7501]
data2 = {"x": x_test, "y": y_test}
df = pd.DataFrame(data2)
x_test = df.iloc[:,:-1]
y_test = df.iloc[:,-1]

# %%
#Graficando
fig, ax = plt.subplots(figsize=(10,5), dpi=100)
ax.set_title('Consumo vs capacidad de memoria necesaria (test set)')
ax.set_xlabel('Consumo megas')
ax.set_ylabel('capacidad de memoria necesaria')
ax = plt.scatter(x_test, y_test, s=100)
ax = plt.plot(x_test, model_regression.predict(x_test), color='red')
plt.show()

# %%
model_regression.predict(x_test)
# Out:
# array([17501.24622005, 20001.24192709,  7501.26339189])
